# %% [markdown]
# <a href="https://colab.research.google.com/github/almunawar12/Artificial-Intelligence/blob/main/Pertemuan6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f8cd48b6-eb67-4ed2-aaae-c88143b2ffc5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8cd48b6-eb67-4ed2-aaae-c88143b2ffc5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd 

data = pd.read_csv('InternetUser.csv')

data.head()
# Out:
#   Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0      M             White        1972              M                  8
# 1      M          Hispanic        1981              S                 14
# 2      F  African American        1977              S                  6
# 3      F             White        1961              D                  8
# 4      M             White        1954              M                  2
#
#    Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# 0              1            Firefox                  Google           Yahoo
# 1              2             Chrome                  Google         Hotmail
# 2              2            Firefox                   Yahoo           Yahoo
# 3              6            Firefox                  Google         Hotmail
# 4              3  Internet Explorer                    Bing         Hotmail
#
#   Read_News Online_Shopping Online_Gaming Facebook Twitter  \
# ...

# %%
print(data['Online_Gaming'].isna().sum())
# Out:
# 3

# %%
data['Online_Gaming'].fillna('N', inplace = True)

# %%
print(data['Online_Gaming'].isna().sum())
# Out:
# 0

# %%
print(data['Read_News'].isna().sum())
# Out:
# 1

# %%
print(data['Online_Shopping'].isna().sum())
# Out:
# 2

# %%
data['Online_Shopping'].fillna('N', inplace = True)

# %%
print(data['Online_Shopping'].isna().sum())
# Out:
# 0

# %%
print(data['Other_Social_Network'].isna().sum())
# Out:
# 7

# %%
data['Other_Social_Network'].fillna('LinkedIn', inplace = True)

# %%
print(data['Other_Social_Network'].isna().sum())
# Out:
# 0

# %%
data['Twitter'].replace(['99'], ['N'], inplace=True)

# %%
print(data['Twitter'].value_counts())
# Out:
# N    9
# Y    2
# Name: Twitter, dtype: int64

# %%
data
# Out:
#    Gender              Race  Birth_Year Marital_Status  Years_on_Internet  \
# 0       M             White        1972              M                  8
# 1       M          Hispanic        1981              S                 14
# 2       F  African American        1977              S                  6
# 3       F             White        1961              D                  8
# 4       M             White        1954              M                  2
# 5       M  African American        1982              D                 15
# 6       M  African American        1981              D                 11
# 7       M             White        1977              S                  3
# 8       F  African American        1969              M                  6
# 9       M             White        1987              S                 12
# 10      F          Hispanic        1959              D                 12
#
#     Hours_Per_Day  Preferred_Browser Preferred_Search_Engine Preferred_Email  \
# ...
